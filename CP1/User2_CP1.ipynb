# %%
# !pip install -q flwr

import flwr as fl
import tensorflow as tf
from google.colab import drive
import numpy as np
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.0/732.0 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.1/250.1 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 44.0.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.3 which is incompatible.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
CLIENT_ID = 2


drive.mount('/content/drive', force_remount=True)

DRIVE_DATA_PATH = '/content/drive/Shareddrives/FedSynDrive/Data'
data_path = os.path.join(DRIVE_DATA_PATH, f'client_{CLIENT_ID}_data.npz')

print(f"--- This notebook is now CLIENT #{CLIENT_ID} ---")
print(f"Loading data from: {data_path}")

with np.load(data_path) as data:
    x_train = data['x'].astype(np.float32)
    y_train = data['y']
    if x_train.ndim == 3:
        x_train = np.expand_dims(x_train, axis=3)

print(f"Successfully loaded {len(x_train)} samples and labels for this client.")
# Out:
# Mounted at /content/drive
# --- This notebook is now CLIENT #2 ---
# Loading data from: /content/drive/Shareddrives/FedSynDrive/Data/client_2_data.npz
# Successfully loaded 20000 samples and labels for this client.

# %%
def create_cnn_model():
    """This must have the exact same architecture as the server's model."""
    model = Sequential([
        Conv2D(32, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1)),
        MaxPool2D(pool_size=(2, 2)),
        Conv2D(64, kernel_size=(5, 5), activation='relu'),
        MaxPool2D(pool_size=(2, 2)),
        Flatten(),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

class CnnClient(fl.client.NumPyClient):
    def __init__(self, model, x_train, y_train):
        self.model = model
        self.x_train = x_train
        self.y_train = y_train

    def get_parameters(self, config):
        return self.model.get_weights()

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        self.model.fit(self.x_train, self.y_train, epochs=1, batch_size=32, verbose=0)
        return self.model.get_weights(), len(self.x_train), {}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        loss, accuracy = self.model.evaluate(self.x_train, self.y_train, verbose=0)
        return loss, len(self.x_train), {"accuracy": accuracy}

# %%
print(f"\n--- Starting Client #{CLIENT_ID} ---")

model = create_cnn_model()
client = CnnClient(model, x_train, y_train)

fl.client.start_numpy_client(
    server_address="35.184.5.50:8888",
    client=client
)

print(f"\n--- Client #{CLIENT_ID} has finished. ---")
# Out:
# --- Starting Client #2 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING :   DEPRECATED FEATURE: flwr.client.start_numpy_client() is deprecated.
# 	Instead, use `flwr.client.start_client()` by ensuring you first call the `.to_client()` method as shown below:
# 	flwr.client.start_client(
# 		server_address='<IP>:<PORT>',
# 		client=FlowerClient().to_client(), # <-- where FlowerClient is of type flwr.client.NumPyClient object
# 	)
# 	Using `start_numpy_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.client.start_numpy_client() is deprecated.
# 	Instead, use `flwr.client.start_client()` by ensuring you first call the `.to_client()` method as shown below:
# 	flwr.client.start_client(
# 		server_address='<IP>:<PORT>',
# 		client=FlowerClient().to_client(), # <-- where FlowerClient is of type flwr.client.NumPyClient object
# 	)
# 	Using `start_numpy_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# DEBUG:flwr:Opened insecure gRPC connection (no certificates were passed)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# DEBUG:flwr:ChannelConnectivity.IDLE
# DEBUG:flwr:ChannelConnectivity.CONNECTING
# DEBUG:flwr:ChannelConnectivity.READY
# INFO :
# INFO:flwr:
# INFO :      Received: train message 1b6fceed-8766-4947-b1ff-ae499a3a72f7
# INFO:flwr:Received: train message 1b6fceed-8766-4947-b1ff-ae499a3a72f7
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message d51cc7e0-15d3-425e-91eb-c6283b48dc59
# INFO:flwr:Received: evaluate message d51cc7e0-15d3-425e-91eb-c6283b48dc59
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message f215a3e0-398e-4d28-a5cb-03e1c6d2bf97
# INFO:flwr:Received: train message f215a3e0-398e-4d28-a5cb-03e1c6d2bf97
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message fd0b310f-70fb-46ab-884c-da18ee3b58d7
# INFO:flwr:Received: evaluate message fd0b310f-70fb-46ab-884c-da18ee3b58d7
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message b79951c5-bd7e-4b40-899a-c11278c27276
# INFO:flwr:Received: train message b79951c5-bd7e-4b40-899a-c11278c27276
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message f4429607-fc5d-48b3-aa05-19fb94a1fafd
# INFO:flwr:Received: evaluate message f4429607-fc5d-48b3-aa05-19fb94a1fafd
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 156e7aae-1283-44d9-9c15-cda81be3fcc7
# INFO:flwr:Received: train message 156e7aae-1283-44d9-9c15-cda81be3fcc7
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message ab2b4f6c-e9c7-404f-9ad4-55a456ba0d62
# INFO:flwr:Received: evaluate message ab2b4f6c-e9c7-404f-9ad4-55a456ba0d62
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 6b9aa563-9f31-4ed6-bc49-75ea3e364b21
# INFO:flwr:Received: train message 6b9aa563-9f31-4ed6-bc49-75ea3e364b21
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message b73839ad-4876-402a-afa6-b6a102a7b7c3
# INFO:flwr:Received: evaluate message b73839ad-4876-402a-afa6-b6a102a7b7c3
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 85f65fbb-6ae0-41cb-a655-bd5de640386e
# INFO:flwr:Received: train message 85f65fbb-6ae0-41cb-a655-bd5de640386e
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message cd2d8a9f-e34a-4dbe-bf8e-b9c9af93438b
# INFO:flwr:Received: evaluate message cd2d8a9f-e34a-4dbe-bf8e-b9c9af93438b
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 2f10a57b-8955-40a4-bd31-43781a70fcef
# INFO:flwr:Received: train message 2f10a57b-8955-40a4-bd31-43781a70fcef
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message acabcfa4-d006-4d28-bc66-27af5088f389
# INFO:flwr:Received: evaluate message acabcfa4-d006-4d28-bc66-27af5088f389
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message cda7ad4c-9be1-47e4-a2eb-b8a1be5dd3e0
# INFO:flwr:Received: train message cda7ad4c-9be1-47e4-a2eb-b8a1be5dd3e0
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message df9eda26-5ebb-48c1-a4ab-aea5fea1d21d
# INFO:flwr:Received: evaluate message df9eda26-5ebb-48c1-a4ab-aea5fea1d21d
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 4abcc65c-c9d1-4096-a2b8-df7ae97f6a99
# INFO:flwr:Received: train message 4abcc65c-c9d1-4096-a2b8-df7ae97f6a99
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message cee20a01-258e-4773-abfc-653c05184149
# INFO:flwr:Received: evaluate message cee20a01-258e-4773-abfc-653c05184149
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 7b98eb22-23aa-4534-9aab-9e893887bd99
# INFO:flwr:Received: train message 7b98eb22-23aa-4534-9aab-9e893887bd99
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 2789b43f-2bb1-4ac9-8f9a-38edaa124aea
# INFO:flwr:Received: evaluate message 2789b43f-2bb1-4ac9-8f9a-38edaa124aea
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message a5e68401-b40c-4de9-9de5-d25c8a6e6d24
# INFO:flwr:Received: train message a5e68401-b40c-4de9-9de5-d25c8a6e6d24
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 90d6b957-b5d1-45dd-99eb-0fcb0d0f3c95
# INFO:flwr:Received: evaluate message 90d6b957-b5d1-45dd-99eb-0fcb0d0f3c95
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message a1a38336-c8c0-4515-bead-c02d7db575a2
# INFO:flwr:Received: train message a1a38336-c8c0-4515-bead-c02d7db575a2
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message be5a3769-c0bb-47b4-8806-182e8429b798
# INFO:flwr:Received: evaluate message be5a3769-c0bb-47b4-8806-182e8429b798
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message db8c373b-233d-48ec-bc12-855cce47ad54
# INFO:flwr:Received: train message db8c373b-233d-48ec-bc12-855cce47ad54
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 67a45762-11e8-4473-ba1f-8d08a47342b0
# INFO:flwr:Received: evaluate message 67a45762-11e8-4473-ba1f-8d08a47342b0
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message fc2b6b9c-5578-4919-944b-f6d77ef277e0
# INFO:flwr:Received: train message fc2b6b9c-5578-4919-944b-f6d77ef277e0
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message b35287ed-5132-4d23-aeb5-07013cd6f07b
# INFO:flwr:Received: evaluate message b35287ed-5132-4d23-aeb5-07013cd6f07b
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 7f6b98da-4c5d-4c15-8326-2ce9ce558935
# INFO:flwr:Received: train message 7f6b98da-4c5d-4c15-8326-2ce9ce558935
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message ff616e45-e71d-4938-87d0-156c343e03b8
# INFO:flwr:Received: evaluate message ff616e45-e71d-4938-87d0-156c343e03b8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 46905698-af5a-45ce-90c0-a48d39acfde6
# INFO:flwr:Received: train message 46905698-af5a-45ce-90c0-a48d39acfde6
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message b7fa7626-e1e4-4c52-bc54-fecbf541a7dd
# INFO:flwr:Received: evaluate message b7fa7626-e1e4-4c52-bc54-fecbf541a7dd
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 5a5c37bd-05d8-45c4-8ae5-073ef5825501
# INFO:flwr:Received: train message 5a5c37bd-05d8-45c4-8ae5-073ef5825501
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 7e80a3db-535a-4cad-b62a-9bc5d4ea4c76
# INFO:flwr:Received: evaluate message 7e80a3db-535a-4cad-b62a-9bc5d4ea4c76
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 12446433-d79e-49d9-b5aa-95177558d16c
# INFO:flwr:Received: train message 12446433-d79e-49d9-b5aa-95177558d16c
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 8dfa3aa8-e69f-4bc0-93a4-dc0fe8edf863
# INFO:flwr:Received: evaluate message 8dfa3aa8-e69f-4bc0-93a4-dc0fe8edf863
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message ac74381d-7732-4191-acbe-9f2a708b07ba
# INFO:flwr:Received: train message ac74381d-7732-4191-acbe-9f2a708b07ba
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 15999bbc-9b3f-4dd4-9a47-dae24c472400
# INFO:flwr:Received: evaluate message 15999bbc-9b3f-4dd4-9a47-dae24c472400
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message bb5571c2-10e4-4bb0-ba40-c14f878f58e8
# INFO:flwr:Received: train message bb5571c2-10e4-4bb0-ba40-c14f878f58e8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 1b00c113-9c04-4fcc-a203-45fe678f26e9
# INFO:flwr:Received: evaluate message 1b00c113-9c04-4fcc-a203-45fe678f26e9
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message be6e41af-fdd5-4fd7-aa16-450c19b65af0
# INFO:flwr:Received: train message be6e41af-fdd5-4fd7-aa16-450c19b65af0
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message ca3e06b5-0c35-4609-a32d-1e33aa800a48
# INFO:flwr:Received: evaluate message ca3e06b5-0c35-4609-a32d-1e33aa800a48
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 3539966b-e91c-45bf-80bf-aaf524c7b1b5
# INFO:flwr:Received: train message 3539966b-e91c-45bf-80bf-aaf524c7b1b5
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 9a9ff8c8-0afe-4139-b868-cb531030e685
# INFO:flwr:Received: evaluate message 9a9ff8c8-0afe-4139-b868-cb531030e685
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message e1c9c41b-6e07-4b82-bb10-03112a84b359
# INFO:flwr:Received: train message e1c9c41b-6e07-4b82-bb10-03112a84b359
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 9588bd35-8124-49aa-aebb-069583fcd282
# INFO:flwr:Received: evaluate message 9588bd35-8124-49aa-aebb-069583fcd282
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 52beebaf-f516-4053-a2d3-5dbde46829c3
# INFO:flwr:Received: train message 52beebaf-f516-4053-a2d3-5dbde46829c3
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message a059297e-c34f-4987-a352-2a2fbc2cc3e4
# INFO:flwr:Received: evaluate message a059297e-c34f-4987-a352-2a2fbc2cc3e4
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 2c0d0694-85b7-424d-9f11-5664558a4315
# INFO:flwr:Received: train message 2c0d0694-85b7-424d-9f11-5664558a4315
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message bf2a9469-b80c-4f8f-8bb8-2ed262596ca6
# INFO:flwr:Received: evaluate message bf2a9469-b80c-4f8f-8bb8-2ed262596ca6
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 8ed59dd7-b289-478a-859c-34c83a2edc2a
# INFO:flwr:Received: train message 8ed59dd7-b289-478a-859c-34c83a2edc2a
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 80d291fd-45b7-4c29-9f99-9fb2d83744e3
# INFO:flwr:Received: evaluate message 80d291fd-45b7-4c29-9f99-9fb2d83744e3
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message e1bf8a8a-b520-457c-867d-5a4df20456cc
# INFO:flwr:Received: train message e1bf8a8a-b520-457c-867d-5a4df20456cc
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 287eb327-79eb-4567-bb03-fc75ee3032cb
# INFO:flwr:Received: evaluate message 287eb327-79eb-4567-bb03-fc75ee3032cb
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message cd80428c-0e7d-46f1-960c-95ea75693fdc
# INFO:flwr:Received: train message cd80428c-0e7d-46f1-960c-95ea75693fdc
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message e35f597d-c0eb-468a-ac31-339cac43d6eb
# INFO:flwr:Received: evaluate message e35f597d-c0eb-468a-ac31-339cac43d6eb
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message cc648a2f-b613-4ec5-8982-591b9d8e5832
# INFO:flwr:Received: train message cc648a2f-b613-4ec5-8982-591b9d8e5832
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message c90484b2-7079-4720-96f9-94260ef48611
# INFO:flwr:Received: evaluate message c90484b2-7079-4720-96f9-94260ef48611
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message b7091301-b186-464a-b2a4-e0a91cbe70bf
# INFO:flwr:Received: train message b7091301-b186-464a-b2a4-e0a91cbe70bf
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message f71f185f-30d2-4a01-8a48-df533059147d
# INFO:flwr:Received: evaluate message f71f185f-30d2-4a01-8a48-df533059147d
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: reconnect message 166d163e-43dc-4541-bf74-415022a4858e
# INFO:flwr:Received: reconnect message 166d163e-43dc-4541-bf74-415022a4858e
# DEBUG:flwr:gRPC channel closed
# INFO :      Disconnect and shut down
# INFO:flwr:Disconnect and shut down
# --- Client #2 has finished. ---
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
